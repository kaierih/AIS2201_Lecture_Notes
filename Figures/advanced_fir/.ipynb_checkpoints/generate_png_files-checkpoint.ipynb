# %% [markdown]
# # Minimum Mean Square Error Illustration

# %%
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure(figsize=(5,5))
ax = fig.subplots()
# Move the left and bottom spines to x = 0 and y = 0, respectively.
ax.spines["left"].set_position(("data", 0))
ax.spines["bottom"].set_position(("data", 0))
# Hide the top and right spines.
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)

# Create axis arrows
ax.plot(1, 0, ">k", transform=ax.get_yaxis_transform(), clip_on=False)
ax.plot(0, 1, "^k", transform=ax.get_xaxis_transform(), clip_on=False)


x = np.linspace(-0, 2., 100)
ax.plot(x, (x-1)**2+0.5)
ax.plot([1,1],[0, 0.5], color="tab:blue", linestyle=":")
ax.plot([1],[0.5], color="tab:blue", marker="o")
plt.yticks([])
plt.xticks([1],["$\\vec{h}_{opt}$"], fontsize=12)
ax.set_ylabel("$\\text{MSE}\\left(\\vec{h}\\right)$", fontsize=12)


# Annotate the marker with "MMSE"
ax.annotate("MMSE", xy=(1, 0.5), xytext=(1.1, 0.7),
            textcoords='data', fontsize=12, color='k',
            arrowprops=dict(arrowstyle="->", color='k'))

#plt.xlabel("h", loc="right")
# Set axis labels at the end of arrows
ax.text(ax.get_xlim()[1]*1.04, -ax.get_ylim()[1]*.02, '$\\vec{h}$', fontsize=12, ha='center')
#ax.text(0, ax.get_ylim()[1]*1.05, r'$e$', fontsize=12, va='center')

plt.savefig("MMSE.png")

# %% [markdown]
# # Circuit Diagram

# %%
# %load_ext jupyter_tikz
# Out:
# The jupyter_tikz extension is already loaded. To reload it, use:
#   %reload_ext jupyter_tikz

# %%
# %%tikz
# \begin{tikzpicture}
#     \draw[help lines] grid (5, 5);
#     \draw[fill=black!10] (1, 1) rectangle (2, 2);
#     \draw[fill=black!10] (2, 1) rectangle (3, 2);
#     \draw[fill=black!10] (3, 1) rectangle (4, 2);
#     \draw[fill=black!10] (3, 2) rectangle (4, 3);
#     \draw[fill=black!10] (2, 3) rectangle (3, 4);
# \end{tikzpicture}
# Out:
# This is pdfTeX, Version 3.141592653-2.6-1.40.25 (MiKTeX 24.1) (preloaded format=pdflatex.fmt)
#  restricted \write18 enabled.
# entering extended mode
# ! Undefined control sequence.
# <*> C:\Users
#             \kaierih\OneDrive - NTNU\AIS2201-Signal_Processing_Public\AIS220...
#
# ?
# ! Emergency stop.
# <*>
#
# !  ==> Fatal error occurred, no output PDF file produced!
# Transcript written on ?.

# %%
from jupyter_tikz import TexFragment

tikz_code = tex_template_code = r"""\begin{tikzpicture}
    \draw[help lines] grid (5, 5);
     \filldraw [color=orange, opacity=0.3] (2.5,2.5) circle (1.5);
\end{tikzpicture}"""

tikz = TexFragment(tikz_code)  # Create the tex template object

tikz.run_latex()  # Run LaTeX and shows the output
# Out:
# This is pdfTeX, Version 3.141592653-2.6-1.40.25 (MiKTeX 24.1) (preloaded format=pdflatex.fmt)
#  restricted \write18 enabled.
# entering extended mode
# ! Undefined control sequence.
# <*> C:\Users
#             \kaierih\OneDrive - NTNU\AIS2201-Signal_Processing_Public\AIS220...
#
# ?
# ! Emergency stop.
# <*>
#
# !  ==> Fatal error occurred, no output PDF file produced!
# Transcript written on ?.

# %%
# !latex wiener_filter.tex
# Out:
# This is pdfTeX, Version 3.141592653-2.6-1.40.25 (MiKTeX 24.1) (preloaded format=latex.fmt)
#  restricted \write18 enabled.
# entering extended mode
# (wiener_filter.tex
# LaTeX2e <2023-11-01> patch level 1
# L3 programming layer <2024-01-04>
# (prefix.tex
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/latex/standalone\standalone
# .cls
# Document Class: standalone 2022/10/10 v1.3b Class to compile TeX sub-files stan
# dalone
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/latex/tools\shellesc.sty)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/iftex\ifluatex.sty
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/iftex\iftex.sty))
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/latex/xkeyval\xkeyval.sty
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/xkeyval\xkeyval.tex
#
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/xkeyval\xkvutils.te
# x
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/xkeyval\keyval.tex)
# )))
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/latex/standalone\standalone
# .cfg)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/latex/base\article.cls
# Document Class: article 2023/05/17 v1.4n Standard LaTeX document class
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/latex/base\size10.clo))
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/latex/pgf/frontendlayer\tik
# z.sty
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/latex/pgf/basiclayer\pgf.st
# y
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/latex/pgf/utilities\pgfrcs.
# sty
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/utilities\pgfut
# il-common.tex)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/utilities\pgfut
# il-latex.def)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/utilities\pgfrc
# s.code.tex
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf\pgf.revision.te
# x)))
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/latex/pgf/basiclayer\pgfcor
# e.sty
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/latex/graphics\graphicx.sty
#
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/latex/graphics\graphics.sty
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/latex/graphics\trig.sty)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/latex/graphics-cfg\graphics
# .cfg)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/latex/graphics-def\dvips.de
# f)))
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/latex/pgf/systemlayer\pgfsy
# s.sty
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/systemlayer\pgf
# sys.code.tex
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/utilities\pgfke
# ys.code.tex
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/utilities\pgfke
# yslibraryfiltered.code.tex))
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/systemlayer\pgf
# .cfg)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/systemlayer\pgf
# sys-dvips.def
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/systemlayer\pgf
# sys-common-postscript.def)))
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/systemlayer\pgf
# syssoftpath.code.tex)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/systemlayer\pgf
# sysprotocol.code.tex))
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/latex/xcolor\xcolor.sty
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/latex/graphics-cfg\color.cf
# g)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/latex/graphics\mathcolor.lt
# x))
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/basiclayer\pgfc
# ore.code.tex
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/math\pgfmath.co
# de.tex
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/math\pgfmathuti
# l.code.tex)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/math\pgfmathpar
# ser.code.tex)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/math\pgfmathfun
# ctions.code.tex)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/math\pgfmathfun
# ctions.basic.code.tex)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/math\pgfmathfun
# ctions.trigonometric.code.tex)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/math\pgfmathfun
# ctions.random.code.tex)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/math\pgfmathfun
# ctions.comparison.code.tex)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/math\pgfmathfun
# ctions.base.code.tex)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/math\pgfmathfun
# ctions.round.code.tex)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/math\pgfmathfun
# ctions.misc.code.tex)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/math\pgfmathfun
# ctions.integerarithmetics.code.tex)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/math\pgfmathcal
# c.code.tex)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/math\pgfmathflo
# at.code.tex))
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/math\pgfint.cod
# e.tex)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/basiclayer\pgfc
# orepoints.code.tex)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/basiclayer\pgfc
# orepathconstruct.code.tex)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/basiclayer\pgfc
# orepathusage.code.tex)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/basiclayer\pgfc
# orescopes.code.tex)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/basiclayer\pgfc
# oregraphicstate.code.tex)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/basiclayer\pgfc
# oretransformations.code.tex)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/basiclayer\pgfc
# orequick.code.tex)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/basiclayer\pgfc
# oreobjects.code.tex)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/basiclayer\pgfc
# orepathprocessing.code.tex)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/basiclayer\pgfc
# orearrows.code.tex)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/basiclayer\pgfc
# oreshade.code.tex)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/basiclayer\pgfc
# oreimage.code.tex)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/basiclayer\pgfc
# oreexternal.code.tex)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/basiclayer\pgfc
# orelayers.code.tex)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/basiclayer\pgfc
# oretransparency.code.tex)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/basiclayer\pgfc
# orepatterns.code.tex)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/basiclayer\pgfc
# orerdf.code.tex)))
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/modules\pgfmodu
# leshapes.code.tex)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/modules\pgfmodu
# leplot.code.tex)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/latex/pgf/compatibility\pgf
# comp-version-0-65.sty)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/latex/pgf/compatibility\pgf
# comp-version-1-18.sty))
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/latex/pgf/utilities\pgffor.
# sty
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/latex/pgf/utilities\pgfkeys
# .sty
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/utilities\pgfke
# ys.code.tex))
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/latex/pgf/math\pgfmath.sty
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/math\pgfmath.co
# de.tex))
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/utilities\pgffo
# r.code.tex))
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/frontendlayer/t
# ikz\tikz.code.tex
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/libraries\pgfli
# braryplothandlers.code.tex)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/modules\pgfmodu
# lematrix.code.tex)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/frontendlayer/t
# ikz/libraries\tikzlibrarytopaths.code.tex)))
# Executing precommand:
# dvips wiener_filter.dvi
#
#
# Executing command:
# gswin32c -dSAFER -dBATCH -dNOPAUSE -sDEVICE=png16m -r3000 -sOutputFile=wiener_f
# ilter.png wiener_filter.ps
#
#
# Class standalone Warning: Conversion failed! Please ensure that shell escape
# (standalone)              is enabled (e.g. use '-shell-escape').
#
# ) (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/latex/amsmath\amsmath.sty
# For additional information on amsmath, use the `?' option.
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/latex/amsmath\amstext.sty
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/latex/amsmath\amsgen.sty))
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/latex/amsmath\amsbsy.sty)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/latex/amsmath\amsopn.sty))
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/latex/amsfonts\amssymb.sty
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/latex/amsfonts\amsfonts.sty
# )) (ss2-figures.sty
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/latex/pgfplots\pgfplots.sty
#
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgfplots\pgfplots.r
# evision.tex)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgfplots\pgfplots.c
# ode.tex
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgfplots\pgfplotsco
# re.code.tex
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgfplots/sys\pgfplo
# tssysgeneric.code.tex))
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgfplots/libs\pgfpl
# otslibrary.code.tex)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgfplots/oldpgfcomp
# atib\pgfplotsoldpgfsupp_loader.code.tex
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/libraries\pgfli
# braryfpu.code.tex)
# Package pgfplots: loading complementary utilities for your pgf version...
#
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgfplots/oldpgfcomp
# atib\pgfplotsoldpgfsupp_pgfutil-common-lists.tex))
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgfplots/util\pgfpl
# otsutil.code.tex
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgfplots/liststruct
# ure\pgfplotsliststructure.code.tex)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgfplots/liststruct
# ure\pgfplotsliststructureext.code.tex)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgfplots/liststruct
# ure\pgfplotsarray.code.tex)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgfplots/liststruct
# ure\pgfplotsmatrix.code.tex)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgfplots/numtable\p
# gfplotstableshared.code.tex)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgfplots/liststruct
# ure\pgfplotsdeque.code.tex)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgfplots/util\pgfpl
# otsbinary.code.tex
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgfplots/util\pgfpl
# otsbinary.data.code.tex))
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgfplots/util\pgfpl
# otsutil.verb.code.tex)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgfplots/libs\pgfli
# brarypgfplots.surfshading.code.tex
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgfplots/sys\pgflib
# rarypgfplots.surfshading.pgfsys-dvips.def)))
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgfplots/util\pgfpl
# otscolormap.code.tex
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgfplots/util\pgfpl
# otscolor.code.tex))
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgfplots\pgfplotsst
# ackedplots.code.tex)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgfplots\pgfplotspl
# othandlers.code.tex
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgfplots\pgfplotsme
# shplothandler.code.tex
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgfplots\pgfplotsme
# shplotimage.code.tex)))
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgfplots\pgfplots.s
# caling.code.tex)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgfplots\pgfplotsco
# ordprocessing.code.tex)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgfplots\pgfplots.e
# rrorbars.code.tex)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgfplots\pgfplots.m
# arkers.code.tex)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgfplots\pgfplotsti
# cks.code.tex)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgfplots\pgfplots.p
# aths.code.tex)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/frontendlayer/t
# ikz/libraries\tikzlibrarydecorations.code.tex
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/modules\pgfmodu
# ledecorations.code.tex))
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/frontendlayer/t
# ikz/libraries\tikzlibrarydecorations.pathmorphing.code.tex
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/libraries/decor
# ations\pgflibrarydecorations.pathmorphing.code.tex))
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/frontendlayer/t
# ikz/libraries\tikzlibrarydecorations.pathreplacing.code.tex
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/libraries/decor
# ations\pgflibrarydecorations.pathreplacing.code.tex))
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgfplots/libs\tikzl
# ibrarypgfplots.contourlua.code.tex))
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/frontendlayer/t
# ikz/libraries\tikzlibraryplotmarks.code.tex
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/libraries\pgfli
# braryplotmarks.code.tex)))
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/latex/circuitikz\circuitikz
# .sty
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/frontendlayer/t
# ikz/libraries\tikzlibrarycalc.code.tex)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/libraries\pgfli
# braryarrows.meta.code.tex)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/frontendlayer/t
# ikz/libraries\tikzlibrarybending.code.tex
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/modules\pgfmodu
# lebending.code.tex
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/modules\pgfmodu
# lenonlineartransformations.code.tex)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/libraries\pgfli
# brarycurvilinear.code.tex)))
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/frontendlayer/t
# ikz/libraries\tikzlibraryfpu.code.tex)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/circuitikz\pgfcirc.
# defines.tex)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/circuitikz\pgfcircu
# tils.tex)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/circuitikz\pgfcircp
# ath.tex)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/circuitikz\pgfcircs
# hapes.tex)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/circuitikz\pgfcircm
# onopoles.tex)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/circuitikz\pgfcircb
# ipoles.tex)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/circuitikz\pgfcirct
# ripoles.tex)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/circuitikz\pgfcircq
# uadpoles.tex)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/circuitikz\pgfcircm
# ultipoles.tex)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/circuitikz\pgfcircl
# abel.tex)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/circuitikz\pgfcircv
# oltage.tex)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/circuitikz\pgfcircc
# urrent.tex)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/circuitikz\pgfcircf
# low.tex))
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/frontendlayer/t
# ikz/libraries\tikzlibraryshapes.code.tex
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/frontendlayer/t
# ikz/libraries\tikzlibraryshapes.geometric.code.tex
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/libraries/shape
# s\pgflibraryshapes.geometric.code.tex))
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/frontendlayer/t
# ikz/libraries\tikzlibraryshapes.misc.code.tex
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/libraries/shape
# s\pgflibraryshapes.misc.code.tex))
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/frontendlayer/t
# ikz/libraries\tikzlibraryshapes.symbols.code.tex
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/libraries/shape
# s\pgflibraryshapes.symbols.code.tex))
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/frontendlayer/t
# ikz/libraries\tikzlibraryshapes.arrows.code.tex
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/libraries/shape
# s\pgflibraryshapes.arrows.code.tex))
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/frontendlayer/t
# ikz/libraries\tikzlibraryshapes.callouts.code.tex
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/libraries/shape
# s\pgflibraryshapes.callouts.code.tex))
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/frontendlayer/t
# ikz/libraries\tikzlibraryshapes.multipart.code.tex
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/libraries/shape
# s\pgflibraryshapes.multipart.code.tex)))
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/frontendlayer/t
# ikz/libraries\tikzlibrarypositioning.code.tex)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/frontendlayer/t
# ikz/libraries\tikzlibraryarrows.code.tex
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/libraries\pgfli
# braryarrows.code.tex))
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/frontendlayer/t
# ikz/libraries\tikzlibrarypatterns.code.tex
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/generic/pgf/libraries\pgfli
# brarypatterns.code.tex))))
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/latex/l3backend\l3backend-d
# vips.def)
# No file wiener_filter.aux.
# Package pgfplots notification 'compat/show suggested version=true': document ha
# s been generated with the most recent feature set (\pgfplotsset{compat=1.18}).
#
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/latex/amsfonts\umsa.fd)
# (C:\Users\kaierih\AppData\Local\Programs\MiKTeX\tex/latex/amsfonts\umsb.fd)
# [1] (wiener_filter.aux) )
# Output written on wiener_filter.dvi (1 page, 16384 bytes).
# Transcript written on wiener_filter.log.
