# %% [markdown]
# <img src="Figurer/NTNU_Logo.png" align="left" width="30%">
# <br clear="all" />
# <br></br>
#
# # Introduction
#
# * **Course AIS2201 - Signal Processing**
# * **Week 34, 2024**
# * **Lecturer: Kai Erik Hoff**

# %% [markdown]
# # Topics
#
# * Intro to Signal Processing
# * Practical information
# * Digital signal processing using Python

# %% [markdown]
# # Why learn signal processing?

# %% [markdown]
# ### *Any suggestions?*

# %% [markdown]
# # What *is* signal processing?

# %% [markdown]
# 1. ***Signal processing*** focuses on analyzing or manipulating a *signal*, often with the purpose of extracting specific information.

# %% [markdown]
# 2. A ***Signal*** may be any measurable function containing information, which varies with time/location etc...

# %% [markdown]
# 3. Signal processing conducted on a computer or other digital processing unit is known as ***Digital Signal Processing***.

# %% [markdown]
# # Where is digital signal processing used?

# %% [markdown]
#
# <div style="width: 100%;">
#     <img src="Figurer/01_Introduksjon/Fig1_sensorer.png" width="30%" align="right" />
#     <div style="width: 60%">
#     <br>
#     <ul>
#         <li>Practically anywhere we obtain <i>digitized</i> input from the physical world to conduct some task:</li>
#       <ul><li>Computer vision</li>
#         <li>Digital control systems</li>
#         <li>Communication systems</li>
#         <li>Sensory equipment such as radar, sonar, lidar, MRI etc.</li>
#         <li>Much more...</li></ul>
#     </ul>
#     </div>
# </div>

# %% [markdown]
#  # Topics covered in the course AIS2201 - Signal Processing?
#
#
#
# <!--
# * Introduksjon til et omfattende fagområde
#     * Vi skal gjennomgå grunnprinsippene i signalbehandling.
#
#     * Gir et godt grunnlag til videre fordypning i f.eks. diskrét reguleringsteknikk, datasyn eller maskinlæring.
# <br>
#
# * Signalbehandlingsteori i sammenheng med praktisk anvendelse
#     * Teoretiske prinsipp vil utforskes med prosessering av *hele* signal i form av bildefiler, lydfiler m.m.
#
#     * Praktisk bruk involverer ofte behandling av signaler i *sanntid* med hjelp av f.eks. en mikrokontroller. -->

# %% [markdown]
#
# 1. Fundamental theory:
#     * Analysis of predominately digital signals in the time- and frequency domain
#     * Analysis, design and implementation of digital filters

# %% [markdown]
# Signal processing is a large field of study with many areas of specialization.

# %% [markdown]
# 2. Application of theory:
#     * DSP system development/simulation using Python
#     * DSP system implementation on a microprocessor using C/C++

# %% [markdown]
# Almost any situation where digital signal processing principles are used will involve programming. It is therefore essentail to become familiar both with the high-level analysis and design tools which are available, as well as low-level tools used in implementation.

# %% [markdown]
# # Key competences

# %% [markdown]
# * Know how to collect digitized signal information using i microprocessor
#     * Requires programming in C/C++

# %% [markdown]
# * Conduct analysis of digital signals in the time- and frequency domain
#     * Python/Matlab exceptionally useful tools for signal analysis

# %% [markdown]
# * Design and implement digital filters (or potential other DSP systems) to serve a specific need
#     * System design benefits from Python/Matlab
#     * System implementation often requires more hardware-specific programming (C/C++)

# %% [markdown]
# <!--* Mange lignende fag (typisk kalt "signals and systems" internasjonalt) fungerer hovedsakelig som en introduksjon til fagfeltet, og forutsetter nesten at man tar flere fag før man begynner å ta teorien skikkelig i bruk.
# * Selv om jeg ønsker å gi dere forutsetningene for å spesialisere videre i området dersom dere tar mastergrad senere, ønsker jeg i hovedsak å utruste dere med kunnskap om å bruke noen grunnleggende verktøy som dukker opp i mange sammenhenger. Selv om man ikke nødvendigvis hanvner i et typisk "signalbehandlings-yrke".-->

# %% [markdown]
# # Balancing theory and practice
# <img src="Figurer/01_Introduksjon/Fig1_1_Tools.png" width="60%" style="padding:100px" />

# %% [markdown]
# Often, applying signal processing to a specific task will involve a combination of powerful "general purpose" DSP tools such as the FFT or Digital Filters, and then applying some data processing algorithm to the output wich extracts the desired information.
#
# Example: Tone detection / frequency detection of a signal will typically use a fourier transform to present the signal in the frequency domain, before idenitfying peak locations, which translates to frequency.

# %% [markdown]
# # Studying signal processing - some recommendations.
#
# * Requires steady work to cultivate a proper understanding of concepts
# * Assignments are an important part of the course
#     * Python as a tool for learning DSP, not "only programming"
# * Focus on the *why*
#     * Tables of formulas won't get you far
# * Ask questions, we're here to assist (either in the classroom or on e-mail).
#
#
# *The topic may be challenging, but will teach the use of tools which are useful in a variety of applications. Worth the effort!*

# %% [markdown]
# # Signal Processing and Mathematics
#
# * Signal Processing is in general considered a math-heavy topic
# * This course aims to achieve understanding through practical observation/intuition
# * Less emphasis on lengthy mathematical explanations
#     * I am personally fond of graphical explanations where possible
#
# <img src="Figurer/01_Introduksjon/Fig3_GraphicalMath.png" width="60%" align="right"/>
#
# <!--
# # NEEDS MORE!
#
#
# * Matematiske utregninger for hånd med formeloppslag kan være god trening, men gjør det ikke lett å se sammenhenger.
# * Mange regneoperasjoner kan løses intuitivt med en grafisk tilnærming, og kan også gi en bedre forståelse av sammenhengene.-->

# %% [markdown]
# # Programming
#
# * ***Essential*** for analyzing signals and systems.
#     * Graphical representation.
#     * Python main programming language.
# * Lectures make use of both *code examples* og *demos*
#     * *Code examples* to show execution of signal processing operations in Python
#     * *Demos* to visualize DSP principles and support theory.
# * Implementing DSP systems requires programming (often hardware-specific).
#     * We will use **C** to program some STM32 microcontrollers

# %% [markdown]
# ## Python script example: *Sinusoid*

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib ipympl

t = np.linspace(0, 1, 501)
x_t = np.cos(6*np.pi*t)

plt.figure(1, figsize=(12, 5))
plt.plot(t, x_t, color='tab:orange')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Example demo: audio signal analyzer

# %%
from IPython.display import Audio
from scipy.io import wavfile
fs, data = wavfile.read(r'Datafiler/04_Frekvensrepresentasjon/orca.wav') # les audiofilen 'orca.wav' og lagre til variablene 'fs' og 'data'
xn = data/0x8000
Audio(xn, rate=fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# %matplotlib ipympl
from Kildekode._04_Frekvensrepresentasjon import signalAnalyzer
signalAnalyzer(xn, fs);
# Out:
# ...
# Output()
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Course assignments
#
# * Published as collections of Jupyter Notebooks
# * Encompasses multiple aspects of Signal Processing
#     * Testing theoretical understanding of topics
#     * DSP system design and analysis using Python
#     * Real-time DSP system implementation on an STM32 microcontroller
#
# <img src="Figurer/01_Introduksjon/Fig11_STM32.png" width="30%" align="left" />

# %% [markdown]
# # Pre-requisite courses/skills
#
# * Mathematical methods 2 or similar
#     * Differential equations
#     * Complex numbers and functions
#     * Fourier series
#         * Central to Signal Processing
# * Control systems theory
# * Statistics
# * Programming in Python and C/C++
# <br>
# <br>

# %% [markdown]
# # [Practical information](https://ntnu.blackboard.com/webapps/blackboard/content/listContentEditable.jsp?content_id=_2466071_1&course_id=_50427_1&mode=reset)

# %% [markdown]
# # Rough semester overview
# <br>
# <bt>
#
# <img src="Figurer/01_Introduksjon/Semester_overview.png" width="80%" align="left" />

# %% [markdown]
# # Portfoli
#
# * Assignments
# * Group presentation 1
# * Group presentation 2
# * Individual mini-project
# * Reflection notes

# %% [markdown]
# <img src="Figurer/NTNU_Logo.png" align="left" width="30%">
# <br clear="all" />
# <br></br>
#
# # Introduction to digital signals and systems
#
# * **Reading materials: <br>Chapter 1 in the book Understanding Digital Signal Processing**

# %% [markdown]
# # Why do we want to process signals digitally?
#
# * Enables storage and/or furhter processing such as compression, encruption, statistical analysis etc.
# * Processing of digital signals done by software
#     * Signal processing systems can be adjusted on-the-fly
#     * Enables adaptive systems
# * Cost efficient
#     * A microprocessor can be much cheaper to acquire than a precisely tuned analog filter.

# %% [markdown]
# #### *But let's not get ahead of ourselves...*
# * In order to get a digital signal, we must *discretize* a analog signal.

# %% [markdown]
# # Analog signals and their notation
# * Generated by sensor, microphone etc.
#     * E.g. temperature sensor
# * Has a measurable time-varying quantity (such as voltage).
# * Continuous in time
#     - It is, in theory, possible to describe signal value at any point in time.
#
# <div style="width: 80%;">
#     <img src="Figurer/01_Introduksjon/Fig4_AnalogSig.png" width="55%" align="left" />
#     <div style="float: right; width: 35%">
#     <br>
#         <b>Notation</b>:
#         $$x(t), y(t), s(t) \text{  etc...}$$
#     <ul>
#         <li><i>The temperature $s$ in the figure is a continuous function of time $t$.</i></li>
#     </ul>
#     </div>
# </div>

# %% [markdown]
# # Examples of signals: Audio and Images
# <br>
# <img src="Figurer/01_Introduksjon/Fig8_SigEx.png" style="width: 80%; padding:10px" />
#
# * The primary focus of this course is 1-Dimentional signals.
#     * We will make ample use of audio as a method of demonstrating signal processing systems

# %% [markdown]
# # Discretization of signals
# * Representation of signal as a series of *discrete measurements*
# * Achieved by measuring a countinuous equally spaced intervals
#     * Also known as **sampling**
#
# <div style="width: 80%;">
#     <img src="Figurer/01_Introduksjon/Fig5_DigitalSig.png" style="float: left; width: 55%" />
#     <div style="float: right; width: 35%">
#     <br>
#         <b>Notation</b>:
#         $$x[n], y[n], s[n] \text{ etc...}$$<br> $$ \text{ sometimes also } x(n) \text{ etc...}$$
#     <ul>
#         <li><i>The temperature signal in the figure is a "discrete-time" function of sample number
#             </i> $n \in \mathbb{Z}$.</li>
#     </ul>
#     </div>
# </div>

# %% [markdown]
# Important note: once a signal has been discretized, for all intents and purposes, there ***is*** no signal value which exists between integer sample nubers $n$. Without further information to draw conclusions, the original value of the sampled signal could be anything.

# %% [markdown]
# # Discretizing a signal
# <br>
# <img src="Figurer/01_Introduksjon/Fig6_SamplingSys.png" style="width: 50%; margin-left: 20%" />
# <div style="width: 90%;">
#     <img src="Figurer/01_Introduksjon/Fig7_SampleTable.png" style="float: right; width: 50%; padding: 20px" />
#     <div style="float: right; width: 40%">
#     <br>
#     <ul>
#         <li>The computer, microprocessor etc. "sees" a series of numbers.</li>
#         <li>Kan nå behandles av en datamaskin.</li>
#     </ul>
#     </div>
# </div>

# %% [markdown]
# # Audio files in Python

# %%
from IPython.display import Audio
from scipy.io import wavfile
import matplotlib.pyplot as plt

fs, data = wavfile.read(r'Datafiler/04_Frekvensrepresentasjon/orca.wav') # les audiofilen 'orca.wav' og lagre til variablene 'fs' og 'data'
xn = data/0x8000

t1 = 2.1 # Timestamp to extract signal value
n1 = int(t1 * fs)

t2 = 2.15
n2 = int(t2 * fs)
xn_slice = xn[n1:n2]

# make an array 't' which starts in t1=2.1s and ends in t2=2.15s with (n2-n1) points

t = np.arange(n1, n2)/fs

plt.close(3); plt.figure(3)
plt.plot(t, xn_slice)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Sample time $T_s$
#
# * Almost all digital signal processing tools assume that a digital signal has been discretized using a *uniform sampling interval between each sample*.
#     * Non-uniform sampling makes DSP ***really*** complicated
# * For time-dependent signals (what we mainly will focus on), this sampling interval $T_s$ is known as the ***sample time***.
# <br><br>
# <img src="Figurer/01_Introduksjon/Fig9_Ts.png" style="width: 80%; margin-left: 100px" />

# %% [markdown]
# # Sampling frequency $f_s$
#
# * ***Sampling frequency*** $f_s$ is a measure of the number of samples discretized per second.
# * Sampling time vs. period:
# $$f_s = \frac{1}{T_s}$$
# * Sample number $n$ $\boldsymbol{\leftrightarrow}$ sample time $t_n$:
# $$t = n\cdot T_s = \frac{n}{f_s}$$
# $$n = \frac{t}{T_s} = t\cdot f_s$$
# * Expression for *ideal* sampling:
# $$x[n] = x(t)|_{t = n\cdot T_s}$$

# %% [markdown]
# # Scaling an audio signal plot

# %% [markdown]
# # System model example for DSP sytem
# <br><br>
# <img src="Figurer/01_Introduksjon/Fig10_SampleSys.png" style="width: 80%; margin-left: 100px" />

# %% [markdown]
# # Possible model realization in Arduino C
#
# ```C++
# const int INPUT_PIN = A0; // Analog inngang
# const int T_S = 50;       // Sampleperiode i millisekund
#
# int buffer[512] = {};
# i=0;
#
# unsigned long next_sample_time = 0;
#
# void setup() {
#   pinMode(INPUT_PIN, INPUT);
# }
# ```
# ```C++
# void loop() {
#   if(millis() >= next_sample_time){
#     next_sample_time += T_S;
#     int new_sample = analogRead(INPUT_PIN);
#     i++;
#     buffer[i] = new_sample;
#     /* -----------------------------------
#      * Digital Signal Processing Happens Here!
#      * -----------------------------------
#      */
#   }
#   if (i == 512){
#    # Send buffer over USB etc
#   }
# }
# ```
#
#
#
#
# <br>
# Hello!

# %% [markdown]
# As you may suspect, there are more reliable ways to achieve precise and high-speed uniform sampling. We will explore these further in lab 3.

# %% [markdown]
# # Example
# 1. An analog recording is sampled using a sampling frequency $f_s = 8000Hz$. The first sample is taken at time $=0$.
#     - Which samples represent the audio recording in the time interval $0.25s \leq t < 0.625s$?
#     - Assuming 16 bits per sample, how much storage space is required to store one secoond of recording?

# %% [markdown]
# # Processing the discretized signals
#
# * Once we have the sampled signal values, they are typically processed using basic mathematical operations
#
# <img src="Figurer/10_Digitale Filtre Intro/Fig9_Blocks.png" style="width: 80%" />

# %% [markdown]
# # Two common LTI systems
#
# 1. ***Moving Average Filter:***
#     * Each sample in the output signal $y[n]$ is the average of $L$ most recent samples of the input $x[n]$
#     * Example: 5-point moving average filter
# $$y[n] = \frac{1}{5}x[n] + \frac{1}{5}x[n-1] + \frac{1}{5}x[n-2] + \frac{1}{5}x[n-3] + \frac{1}{5}x[n-4]$$
#
#
# 2. ***Exponential Averager:***
#     * Output $y[n]$ is calculated based on previous output $y[n-1]$ and current input $x[n]$
#     * Example:
# $$y[n] = 0.9 \cdot y[n-1] + 0.1 \cdot x[n]$$

# %%
import scipy.signal as sig
N = 128
n = np.arange(N)
xn = sig.square(2*np.pi*1.5*n/N)

a_1, b_1 = [1], np.ones(20)/20
a_2, b_2 = [1, -0.9], [0.1]

y1 = sig.lfilter(b_1, a_1, xn)
y2 = sig.lfilter(b_2, a_2, xn)

plt.figure()
plt.stem(xn, markerfmt='.')
plt.stem(y1, markerfmt="x", linefmt="C1", label="$y[n]$ (middelverdifilter)")
plt.stem(y2, markerfmt="d", linefmt="C2", label="$y_2[n]$ (eksponentielt glattefilter)")
plt.legend(loc="lower right")
plt.xlim([0, N-1])
# Out:
# (0.0, 127.0)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Example: LTI system implementation on Arduino
#
# <pre>
# <font color="#00979c">float</font> <font color="#000000">prev_y</font> <font color="#434f54">=</font> <font color="#000000">0</font><font color="#000000">;</font> &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<font color="#434f54">&#47;&#47; Global variable to store one sample between function calls</font>
# <font color="#00979c">const</font> <font color="#00979c">float</font> <font color="#000000">ALPHA</font> <font color="#434f54">=</font> <font color="#000000">0.9</font><font color="#000000">;</font> <font color="#434f54">&#47;&#47; Scaling constants in the filter (filter coefficients)</font>
#
# <font color="#95a5a6">&#47;* Function to process one single input value &#39;x&#39;, and return </font>
# <font color="#95a5a6"> * &nbsp;a output sample &#39;y&#39; using an exponential averaging filter.</font>
# <font color="#95a5a6"> * &nbsp;Filter response time is determined by the global constant</font>
# <font color="#95a5a6"> * &nbsp;ALPHA.</font>
# <font color="#95a5a6"> *&#47;</font>
# <font color="#00979c">float</font> <font color="#000000">filter_sample</font><font color="#000000">(</font><font color="#00979c">float</font> <font color="#000000">x</font><font color="#000000">)</font>
# <font color="#000000">{</font>
#  &nbsp;<font color="#00979c">float</font> <font color="#000000">y</font> <font color="#434f54">=</font> <font color="#000000">prev_y</font><font color="#434f54">*</font><font color="#000000">ALPHA</font> <font color="#434f54">+</font> <font color="#000000">x</font><font color="#434f54">*</font><font color="#000000">(</font><font color="#000000">1</font><font color="#434f54">-</font><font color="#000000">ALPHA</font><font color="#000000">)</font><font color="#000000">;</font> <font color="#434f54">&#47;&#47; Perform scaling of y[n-1] by ALPHA</font>
#  &nbsp;<font color="#000000">y</font> <font color="#434f54">+=</font> <font color="#000000">x</font><font color="#434f54">*</font><font color="#000000">(</font><font color="#000000">1</font><font color="#434f54">-</font><font color="#000000">ALPHA</font><font color="#000000">)</font><font color="#000000">;</font> <font color="#434f54">&#47;&#47; Perform scaling of x[n] by (1-ALPHA), and add to y[n]</font>
#  &nbsp;<font color="#000000">prev_y</font> <font color="#434f54">=</font> <font color="#000000">y</font><font color="#000000">;</font>
#  &nbsp;<font color="#95a5a6">&#47;* Store the newly newly calculated output y[n] in variable &#34;prev_y&#34;.</font>
# <font color="#95a5a6"> &nbsp;&nbsp;* &#34;prev_y&#34; will now contain the correct value for y[n-1] the next time </font>
# <font color="#95a5a6"> &nbsp;&nbsp;* &#34;filter_sample&#34;is called. *&#47;</font>
#  &nbsp;<font color="#5e6d03">return</font> <font color="#000000">y</font><font color="#000000">;</font>
# <font color="#000000">}</font>
#
# </pre>

# %% [markdown]
# # Any Questions?
